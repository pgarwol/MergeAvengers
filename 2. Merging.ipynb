# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import spacy
import re

from concurrent.futures import ThreadPoolExecutor # klasa przydatna do multi-threadingu

# %%
nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser'])

df_timestamps = pd.read_csv('with_timestamps.csv', index_col=0)
df_who_said = pd.read_csv('who_said_splitted.csv', index_col=0)

print(df_timestamps.head(2))
print('='*80)
print(df_who_said.head(2))
print('='*50)
print(df_timestamps.shape, df_who_said.shape)
# Out:
#                                         line         start           end
# 0       Report to your stations immediately.  00:00:42,800  00:00:44,802
# 1  This is not a drill. We are under attack!  00:00:44,960  00:00:47,721
# ================================================================================
#      speaker                                 line
# 0  Announcer  Report to your stations immediately
# 1  Announcer                  This is not a drill
# ==================================================
# (1893, 3) (1847, 2)

# %% [markdown]
# ### Usuwanie interpunkcji, żeby zwiększyć poziom similarity

# %%
'''
usuwamy znaki interpunkcyjne, bo wpływa to mocno na spacy.similarity

'''

def remove_punctuation(line: str):
    if isinstance(line, str):
        doc = nlp(line)
        tokens = []
        for token in doc:
            if token.text.isalnum():
                tokens.append(token.text.lower())

        return ' '.join(tokens)
    else:
        return ''


'''
aplikujemy metodę dla całej kolumny "line" jednocześnie i zapisujemy rezultat w nowej kolumnie "with_no_punctuation"

'''
 
df_timestamps['with_no_punctuation'] = df_timestamps['line'].apply(remove_punctuation)
print(df_timestamps['with_no_punctuation'])
# Out:
# 0           report to your stations immediately
# 1       this is not a drill we are under attack
# 2                           we are under attack
# 3                                          shit
# 4                                      language
#                          ...
# 1888                  they good they not a team
# 1889                   let beat them into shape
# 1890                                   avengers
# 1891                                       fine
# 1892                             i do it myself
# Name: with_no_punctuation, Length: 1893, dtype: object

# %%
'''
mapujemy do kategorii, bo jest to bardziej useful -> lepiej operować na dtype.category niż dtype.object

''' 

def map_to_category(similarity: float):
    if similarity == 1.0:
        return '100%'
    elif 0.9 <= similarity < 1.0:
        return r'90% - 99%'
    elif 0.8 <= similarity < 0.9:
        return r'80% - 89%'
    else:
        return '< 80%'

# %%
def match_lines():
    comparison_range = 20 # zasięg indeksów, w których szukamy podobnych zdań -> osobę, która je wypowiedziała
    for i, row in df_timestamps.iterrows():
        if i > 600: # z czasem dwa dataframy się delikatnie rozjezdzają
            comparison_range = 30
        if i > 1600: # a czasem bardziej
            comparison_range = 60


        time_line = nlp(row['with_no_punctuation']) # obiekt spacy, który tokenizuje sobie stringa

        # ustawiamy dolny limit w taki sposób, żeby nie było index out of range (np. i < 0)
        # ta konstrukcja to pythonowski ternary operator (tak jak w C# a > b ? a : b)
        bottom_limit = i-comparison_range if i-comparison_range >= 0 else i
        highest_similarity = 0

        for j in range(bottom_limit, min(i + 1 + comparison_range, len(df_who_said))):
            compared_row = df_who_said.loc[j]
            # znowu robimy obiekt spacy, który tokenizuje sobie stringa
            compared_line = nlp(remove_punctuation(compared_row['line']))
            similarity = time_line.similarity(compared_line)

            # jeżeli najbardziej zbliżony jak do tej pory, to podmieniamy dane
            if similarity >= highest_similarity:
                df_timestamps.at[i, 'who_said'] = df_who_said.iloc[j]['speaker']
                df_timestamps.at[i, 'similarity'] = np.round(similarity, 2)
                df_timestamps.at[i, 'similarity_category'] = map_to_category(np.round(similarity, 2))
                df_timestamps.at[i, 'similar_line'] = compared_row['line']
                highest_similarity = similarity
                
                
with ThreadPoolExecutor(max_workers=4) as executor:
    future = executor.submit(match_lines)

# %%
# konwertujemy typ danych kolumny (dtype) z object na category 
categories = pd.CategoricalDtype(['< 80%', r'80% - 89%', r'90% - 99%', '100%'], ordered=True)
df_timestamps['similarity_category'] = df_timestamps['similarity_category'].astype(categories)

# dla wygody i estetyki zmieniamy kolejność kolumn i zapisujemy do nowego DataFramu
df = df_timestamps[['start', 'end', 'who_said', 'line', 'similar_line', 'similarity', 'similarity_category']]
df.to_csv('merged.csv')

# %%
print(df.similarity_category.value_counts(normalize=True))
# Out:
# 100%         0.451664
# 90% - 99%    0.187005
# 80% - 89%    0.185420
# < 80%        0.175911
# Name: similarity_category, dtype: float64

# %% [markdown]
# <hr>

# %% [markdown]
# ### Następnym krokiem będzie polepszenie niektórych wierszy

# %%
df = pd.read_csv('merged.csv', index_col=0) # z tym zakończyliśmy etap 2.
compared_df = pd.read_csv('who_said_splitted.csv', index_col=0) # ponownie do tego samego .csv będziemy porównywać
df
# Out:
#              start           end          who_said  \
# 0     00:00:42,800  00:00:44,802         Announcer
# 1     00:00:44,960  00:00:47,721         Announcer
# 2     00:00:49,120  00:00:51,088         Announcer
# 3     00:01:52,200  00:01:54,487        Tony Stark
# 4     00:01:52,200  00:01:54,487      Steve Rogers
# ...            ...           ...               ...
# 1888  02:10:42,400  02:10:44,801      Steve Rogers
# 1889  02:10:44,960  02:10:46,610  Natasha Romanoff
# 1890  02:11:05,080  02:11:06,605      Steve Rogers
# 1891  02:13:25,440  02:13:26,885            Thanos
# 1892  02:13:28,320  02:13:30,163            Thanos
#
#                                            line  \
# 0          Report to your stations immediately.
# 1     This is not a drill. We are under attack!
# 2                          We are under attack!
# 3                                         Shit!
# 4                                     Language!
# ...                                         ...
# 1888          They're good. They're not a team.
# 1889                Let's beat them into shape.
# 1890                                Avengers...
# 1891                                      Fine.
# 1892                         I'll do it myself.
#
#                              similar_line  similarity similarity_category
# 0     Report to your stations immediately        1.00                100%
# 1                     This is not a drill        0.90           90% - 99%
# 2                     We are under attack        1.00                100%
# 3                                    Shit        1.00                100%
# 4                                Language        1.00                100%
# ...                                   ...         ...                 ...
# 1888                   They're not a team        0.97           90% - 99%
# 1889            Let's beat 'em into shape        0.96           90% - 99%
# 1890                             Avengers        1.00                100%
# 1891              Fine, I'll do it myself        0.46               < 80%
# 1892              Fine, I'll do it myself        0.99           90% - 99%
#
# [1893 rows x 7 columns]

# %%
df['previously_similar'] = df['similar_line']
df
# Out:
#              start           end          who_said  \
# 0     00:00:42,800  00:00:44,802         Announcer
# 1     00:00:44,960  00:00:47,721         Announcer
# 2     00:00:49,120  00:00:51,088         Announcer
# 3     00:01:52,200  00:01:54,487        Tony Stark
# 4     00:01:52,200  00:01:54,487      Steve Rogers
# ...            ...           ...               ...
# 1888  02:10:42,400  02:10:44,801      Steve Rogers
# 1889  02:10:44,960  02:10:46,610  Natasha Romanoff
# 1890  02:11:05,080  02:11:06,605      Steve Rogers
# 1891  02:13:25,440  02:13:26,885            Thanos
# 1892  02:13:28,320  02:13:30,163            Thanos
#
#                                            line  \
# 0          Report to your stations immediately.
# 1     This is not a drill. We are under attack!
# 2                          We are under attack!
# 3                                         Shit!
# 4                                     Language!
# ...                                         ...
# 1888          They're good. They're not a team.
# 1889                Let's beat them into shape.
# 1890                                Avengers...
# 1891                                      Fine.
# 1892                         I'll do it myself.
#
#                              similar_line  similarity similarity_category  \
# 0     Report to your stations immediately        1.00                100%
# 1                     This is not a drill        0.90           90% - 99%
# 2                     We are under attack        1.00                100%
# 3                                    Shit        1.00                100%
# 4                                Language        1.00                100%
# ...                                   ...         ...                 ...
# 1888                   They're not a team        0.97           90% - 99%
# 1889            Let's beat 'em into shape        0.96           90% - 99%
# 1890                             Avengers        1.00                100%
# 1891              Fine, I'll do it myself        0.46               < 80%
# 1892              Fine, I'll do it myself        0.99           90% - 99%
#
#                        previously_similar
# 0     Report to your stations immediately
# 1                     This is not a drill
# 2                     We are under attack
# 3                                    Shit
# 4                                Language
# ...                                   ...
# 1888                   They're not a team
# 1889            Let's beat 'em into shape
# 1890                             Avengers
# 1891              Fine, I'll do it myself
# 1892              Fine, I'll do it myself
#
# [1893 rows x 8 columns]

# %%
'''
Szukamy wszystkich kotwic. Pomiędzy nimi będziemy szukać braków. 
Wstępnie ustalamy kotwice na wiersze, w których similiarity > 0.95

'''

df['is_anchor'] = df.similarity >= 0.95
df
# Out:
#              start           end          who_said  \
# 0     00:00:42,800  00:00:44,802         Announcer
# 1     00:00:44,960  00:00:47,721         Announcer
# 2     00:00:49,120  00:00:51,088         Announcer
# 3     00:01:52,200  00:01:54,487        Tony Stark
# 4     00:01:52,200  00:01:54,487      Steve Rogers
# ...            ...           ...               ...
# 1888  02:10:42,400  02:10:44,801      Steve Rogers
# 1889  02:10:44,960  02:10:46,610  Natasha Romanoff
# 1890  02:11:05,080  02:11:06,605      Steve Rogers
# 1891  02:13:25,440  02:13:26,885            Thanos
# 1892  02:13:28,320  02:13:30,163            Thanos
#
#                                            line  \
# 0          Report to your stations immediately.
# 1     This is not a drill. We are under attack!
# 2                          We are under attack!
# 3                                         Shit!
# 4                                     Language!
# ...                                         ...
# 1888          They're good. They're not a team.
# 1889                Let's beat them into shape.
# 1890                                Avengers...
# 1891                                      Fine.
# 1892                         I'll do it myself.
#
#                              similar_line  similarity similarity_category  \
# 0     Report to your stations immediately        1.00                100%
# 1                     This is not a drill        0.90           90% - 99%
# 2                     We are under attack        1.00                100%
# 3                                    Shit        1.00                100%
# 4                                Language        1.00                100%
# ...                                   ...         ...                 ...
# 1888                   They're not a team        0.97           90% - 99%
# 1889            Let's beat 'em into shape        0.96           90% - 99%
# 1890                             Avengers        1.00                100%
# 1891              Fine, I'll do it myself        0.46               < 80%
# 1892              Fine, I'll do it myself        0.99           90% - 99%
#
#                        previously_similar  is_anchor
# 0     Report to your stations immediately       True
# 1                     This is not a drill      False
# 2                     We are under attack       True
# 3                                    Shit       True
# 4                                Language       True
# ...                                   ...        ...
# 1888                   They're not a team       True
# 1889            Let's beat 'em into shape       True
# 1890                             Avengers       True
# 1891              Fine, I'll do it myself      False
# 1892              Fine, I'll do it myself       True
#
# [1893 rows x 9 columns]

# %%
'''
Wybieramy wiersze, dla których szukamy lepszego dopasowania
Wstępnie jest to similarity <= 0.75

'''


df['to_replace'] = df.similarity < 0.75
df
# Out:
#              start           end          who_said  \
# 0     00:00:42,800  00:00:44,802         Announcer
# 1     00:00:44,960  00:00:47,721         Announcer
# 2     00:00:49,120  00:00:51,088         Announcer
# 3     00:01:52,200  00:01:54,487        Tony Stark
# 4     00:01:52,200  00:01:54,487      Steve Rogers
# ...            ...           ...               ...
# 1888  02:10:42,400  02:10:44,801      Steve Rogers
# 1889  02:10:44,960  02:10:46,610  Natasha Romanoff
# 1890  02:11:05,080  02:11:06,605      Steve Rogers
# 1891  02:13:25,440  02:13:26,885            Thanos
# 1892  02:13:28,320  02:13:30,163            Thanos
#
#                                            line  \
# 0          Report to your stations immediately.
# 1     This is not a drill. We are under attack!
# 2                          We are under attack!
# 3                                         Shit!
# 4                                     Language!
# ...                                         ...
# 1888          They're good. They're not a team.
# 1889                Let's beat them into shape.
# 1890                                Avengers...
# 1891                                      Fine.
# 1892                         I'll do it myself.
#
#                              similar_line  similarity similarity_category  \
# 0     Report to your stations immediately        1.00                100%
# 1                     This is not a drill        0.90           90% - 99%
# 2                     We are under attack        1.00                100%
# 3                                    Shit        1.00                100%
# 4                                Language        1.00                100%
# ...                                   ...         ...                 ...
# 1888                   They're not a team        0.97           90% - 99%
# 1889            Let's beat 'em into shape        0.96           90% - 99%
# 1890                             Avengers        1.00                100%
# 1891              Fine, I'll do it myself        0.46               < 80%
# 1892              Fine, I'll do it myself        0.99           90% - 99%
#
#                        previously_similar  is_anchor  to_replace
# 0     Report to your stations immediately       True       False
# 1                     This is not a drill      False       False
# 2                     We are under attack       True       False
# 3                                    Shit       True       False
# 4                                Language       True       False
# ...                                   ...        ...         ...
# 1888                   They're not a team       True       False
# 1889            Let's beat 'em into shape       True       False
# 1890                             Avengers       True       False
# 1891              Fine, I'll do it myself      False        True
# 1892              Fine, I'll do it myself       True       False
#
# [1893 rows x 10 columns]

# %%
nlp = spacy.load("en_core_web_sm", disable=["ner", "parser"])

def remove_punctuation(line: str):
    if isinstance(line, str):
        doc = nlp(line)
        tokens = []
        for token in doc:
            if token.text.isalnum():
                tokens.append(token.text.lower())

        return ' '.join(tokens)
    else:
        return ''


# aplikujemy metodę dla całej kolumny "line" jednocześnie i zapisujemy rezultat w nowej kolumnie "with_no_punctuation"
df['with_no_punctuation'] = df['line'].apply(remove_punctuation)
compared_df['with_no_punctuation'] = compared_df['line'].apply(remove_punctuation)

# %%
anchor_indexes = df[df.is_anchor].index
anchor_indexes = anchor_indexes.to_numpy()

def find_top_anchor(idx: int) -> int:
    tmp = idx
    while idx >= 0:
        if idx in anchor_indexes:
            return idx
        idx -= 1
    return tmp - 20


def find_bot_anchor(idx: int) -> int:
    tmp = idx
    while idx <= df.shape[0]:
        if idx in anchor_indexes:
            return idx
        idx += 1
    return tmp + 20
    

for i, row in df.iterrows():
    time_line = nlp(row['with_no_punctuation'])
    if row['to_replace']:
        # w tych ramach będziemy szukać
        top_anchor = find_top_anchor(i)
        bottom_anchor = find_bot_anchor(i)
        
        subset = compared_df.iloc[top_anchor:bottom_anchor]
        
        highest_similarity = 0
        for j, r in subset.iterrows():
            compared_line = nlp(r['with_no_punctuation'])
            similarity = time_line.similarity(compared_line)
            
            if similarity >= highest_similarity:
                if df.iloc[i]['with_no_punctuation'] == r['with_no_punctuation']:
                    df.at[i, 'was_replaced'] = None # w teorii powinien byc False, ale skróci to linijki potem
                else:
                    df.at[i, 'was_replaced'] = True

                df.at[i, 'who_said'] = r['speaker']
                df.at[i, 'similarity'] = np.round(similarity, 2)
                df.at[i, 'similarity_category'] = map_to_category(np.round(similarity, 2))
                df.at[i, 'similar_line'] = r['line']
                highest_similarity = similarity
    else:
        continue
# Out:
# /var/folders/3n/tfkp4g9d78x17d5jc2zy9bf80000gn/T/ipykernel_36014/607208284.py:34: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = time_line.similarity(compared_line)
# /var/folders/3n/tfkp4g9d78x17d5jc2zy9bf80000gn/T/ipykernel_36014/607208284.py:34: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = time_line.similarity(compared_line)
# /var/folders/3n/tfkp4g9d78x17d5jc2zy9bf80000gn/T/ipykernel_36014/607208284.py:34: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = time_line.similarity(compared_line)

# %%
df
# Out:
#              start           end          who_said  \
# 0     00:00:42,800  00:00:44,802         Announcer
# 1     00:00:44,960  00:00:47,721         Announcer
# 2     00:00:49,120  00:00:51,088         Announcer
# 3     00:01:52,200  00:01:54,487        Tony Stark
# 4     00:01:52,200  00:01:54,487      Steve Rogers
# ...            ...           ...               ...
# 1888  02:10:42,400  02:10:44,801      Steve Rogers
# 1889  02:10:44,960  02:10:46,610  Natasha Romanoff
# 1890  02:11:05,080  02:11:06,605      Steve Rogers
# 1891  02:13:25,440  02:13:26,885            Thanos
# 1892  02:13:28,320  02:13:30,163            Thanos
#
#                                            line  \
# 0          Report to your stations immediately.
# 1     This is not a drill. We are under attack!
# 2                          We are under attack!
# 3                                         Shit!
# 4                                     Language!
# ...                                         ...
# 1888          They're good. They're not a team.
# 1889                Let's beat them into shape.
# 1890                                Avengers...
# 1891                                      Fine.
# 1892                         I'll do it myself.
#
#                              similar_line  similarity similarity_category  \
# 0     Report to your stations immediately        1.00                100%
# 1                     This is not a drill        0.90           90% - 99%
# 2                     We are under attack        1.00                100%
# 3                                    Shit        1.00                100%
# 4                                Language        1.00                100%
# ...                                   ...         ...                 ...
# 1888                   They're not a team        0.97           90% - 99%
# 1889            Let's beat 'em into shape        0.96           90% - 99%
# 1890                             Avengers        1.00                100%
# 1891              Fine, I'll do it myself        0.46               < 80%
# 1892              Fine, I'll do it myself        0.99           90% - 99%
#
#                        previously_similar  is_anchor  to_replace  \
# 0     Report to your stations immediately       True       False
# 1                     This is not a drill      False       False
# 2                     We are under attack       True       False
# 3                                    Shit       True       False
# 4                                Language       True       False
# ...                                   ...        ...         ...
# 1888                   They're not a team       True       False
# 1889            Let's beat 'em into shape       True       False
# 1890                             Avengers       True       False
# 1891              Fine, I'll do it myself      False        True
# 1892              Fine, I'll do it myself       True       False
#
#                           with_no_punctuation was_replaced
# 0         report to your stations immediately          NaN
# 1     this is not a drill we are under attack          NaN
# 2                         we are under attack          NaN
# 3                                        shit          NaN
# 4                                    language          NaN
# ...                                       ...          ...
# 1888                they good they not a team          NaN
# 1889                 let beat them into shape          NaN
# 1890                                 avengers          NaN
# 1891                                     fine          NaN
# 1892                           i do it myself          NaN
#
# [1893 rows x 12 columns]

# %%
def mapping(x):
    if isinstance(x, bool):
        return True
    else:
        return False
df['was_replaced'] = df['was_replaced'].apply(mapping)
df
# Out:
#              start           end          who_said  \
# 0     00:00:42,800  00:00:44,802         Announcer
# 1     00:00:44,960  00:00:47,721         Announcer
# 2     00:00:49,120  00:00:51,088         Announcer
# 3     00:01:52,200  00:01:54,487        Tony Stark
# 4     00:01:52,200  00:01:54,487      Steve Rogers
# ...            ...           ...               ...
# 1888  02:10:42,400  02:10:44,801      Steve Rogers
# 1889  02:10:44,960  02:10:46,610  Natasha Romanoff
# 1890  02:11:05,080  02:11:06,605      Steve Rogers
# 1891  02:13:25,440  02:13:26,885            Thanos
# 1892  02:13:28,320  02:13:30,163            Thanos
#
#                                            line  \
# 0          Report to your stations immediately.
# 1     This is not a drill. We are under attack!
# 2                          We are under attack!
# 3                                         Shit!
# 4                                     Language!
# ...                                         ...
# 1888          They're good. They're not a team.
# 1889                Let's beat them into shape.
# 1890                                Avengers...
# 1891                                      Fine.
# 1892                         I'll do it myself.
#
#                              similar_line  similarity similarity_category  \
# 0     Report to your stations immediately        1.00                100%
# 1                     This is not a drill        0.90           90% - 99%
# 2                     We are under attack        1.00                100%
# 3                                    Shit        1.00                100%
# 4                                Language        1.00                100%
# ...                                   ...         ...                 ...
# 1888                   They're not a team        0.97           90% - 99%
# 1889            Let's beat 'em into shape        0.96           90% - 99%
# 1890                             Avengers        1.00                100%
# 1891              Fine, I'll do it myself        0.46               < 80%
# 1892              Fine, I'll do it myself        0.99           90% - 99%
#
#                        previously_similar  is_anchor  to_replace  \
# 0     Report to your stations immediately       True       False
# 1                     This is not a drill      False       False
# 2                     We are under attack       True       False
# 3                                    Shit       True       False
# 4                                Language       True       False
# ...                                   ...        ...         ...
# 1888                   They're not a team       True       False
# 1889            Let's beat 'em into shape       True       False
# 1890                             Avengers       True       False
# 1891              Fine, I'll do it myself      False        True
# 1892              Fine, I'll do it myself       True       False
#
#                           with_no_punctuation  was_replaced
# 0         report to your stations immediately         False
# 1     this is not a drill we are under attack         False
# 2                         we are under attack         False
# 3                                        shit         False
# 4                                    language         False
# ...                                       ...           ...
# 1888                they good they not a team         False
# 1889                 let beat them into shape         False
# 1890                                 avengers         False
# 1891                                     fine         False
# 1892                           i do it myself         False
#
# [1893 rows x 12 columns]

# %%
output = df[['start', 'end', 'who_said', 'line', 'similar_line', 'similarity', 'similarity_category']]
output.to_csv('mergeAfterAnchoring.csv')

# %%
replaced = df[df.was_replaced==True]
replaced = replaced.loc[:, ['who_said', 'line', 'similar_line', 'previously_similar']].copy()

# %%
replaced
# Out:
#               who_said                   line  \
# 45         Iron Legion                Costel!
# 48         Iron Legion     Avengers, go home!
# 287         Tony Stark  designed by Mr Stark.
# 296             JARVIS              Mr Stark?
# 316             Ultron               May I...
# ...                ...                    ...
# 1781  Natasha Romanoff                Zrinka!
# 1782         Nick Fury          Costel! Baby!
# 1784  Natasha Romanoff                  Fine.
# 1817        Tony Stark                Well...
# 1835      Steve Rogers  Trouble, Ms Romanoff.
#
#                                            similar_line  \
# 45    We wish to avoid collateral damage and will in...
# 48                                  We are here to help
# 287                                       Thanks, buddy
# 296                                               Stark
# 316                                     they can't mean
# ...                                                 ...
# 1781                                              Right
# 1782  But with Stark's stealth tech, we still can't ...
# 1784                                              Right
# 1817                                     Triple Yahtzee
# 1835                                           I'm home
#
#                                      previously_similar
# 45                  Stark, we really need to get inside
# 48                           You didn't see that coming
# 287   You are Ultron, a global peacekeeping initiati...
# 296                                               Stark
# 316                                  I am contacting Mr
# ...                                                 ...
# 1781                                       They're good
# 1782                           And you're gonna miss me
# 1784                                           I'm fine
# 1817         Well, the Vision's artificial intelligence
# 1835                              Nothing lasts forever
#
# [154 rows x 4 columns]

# %%
for i, row in replaced.iterrows():
    print('''
        [{}]
        "{}"
        
        Na podstawie:
        {}
        
        Wcześniejsza opcja:
        {}  
    '''.format(row['who_said'], row['line'], row['similar_line'], row['previously_similar']))
# Out:
#         [Iron Legion]
#         "Costel!"
#
#         Na podstawie:
#         We wish to avoid collateral damage and will inform you when this current conflict is resolved
#
#         Wcześniejsza opcja:
#         Stark, we really need to get inside
#
#
#         [Iron Legion]
#         "Avengers, go home!"
#
#         Na podstawie:
#         We are here to help
#
#         Wcześniejsza opcja:
#         You didn't see that coming
#
#
#         [Tony Stark]
#         "designed by Mr Stark."
#
#         Na podstawie:
#         Thanks, buddy
#
#         Wcześniejsza opcja:
#         You are Ultron, a global peacekeeping initiative designed by Mr
#
#
#         [JARVIS]
#         "Mr Stark?"
#
#         Na podstawie:
#         Stark
#
#         Wcześniejsza opcja:
#         Stark
#
#
#         [Ultron]
#         "May I..."
#
#         Na podstawie:
#         they can't mean
#
#         Wcześniejsza opcja:
#         I am contacting Mr
#
#
#         [Ultron]
#         "Come back, come back, come back."
#
#         Na podstawie:
#         That is too much
#
#         Wcześniejsza opcja:
#         So I take the tank, fly it right up to the General's palace, drop it at his feet, I'm like, Boom
#
#
#         [James Rhodes]
#         "Oh, my goodness."
#
#         Na podstawie:
#         So, no Pepper
#
#         Wcześniejsza opcja:
#         Oh, excuse me
#
#
#         [Sam Wilson]
#         "All right."
#
#         Na podstawie:
#         No, I'm not actually sorry
#
#         Wcześniejsza opcja:
#         You looking for this
#
#
#         [Thor]
#         "Please, be my guest."
#
#         Na podstawie:
#         Well please, be my guest
#
#         Wcześniejsza opcja:
#         All my friends are fighters
#
#
#         [James Rhodes]
#         "This is gonna be beautiful."
#
#         Na podstawie:
#         Oh this is gonna be beautiful
#
#         Wcześniejsza opcja:
#         So what do you think should I fight this, or run with it
#
#
#         [Tony Stark]
#         "Smell the silent judgement?"
#
#         Na podstawie:
#         Smell the silent judgment
#
#         Wcześniejsza opcja:
#         open person in the world
#
#
#         [Maria Hill]
#         "Yes, of course."
#
#         Na podstawie:
#         Okay
#
#         Wcześniejsza opcja:
#         open person in the world
#
#
#         [Clint Barton]
#         "I will be reinstituting prima nocta."
#
#         Na podstawie:
#         Uh, Whosoever be he worthy shall haveth the power
#
#         Wcześniejsza opcja:
#         Well please, be my guest
#
#
#         [Thor]
#         "Are you on my team?"
#
#         Na podstawie:
#         Well please, be my guest
#
#         Wcześniejsza opcja:
#         Well please, be my guest
#
#
#         [Clint Barton]
#         "Just represent. Pull."
#
#         Na podstawie:
#         Please, Stark, by all means
#
#         Wcześniejsza opcja:
#         Look, as maybe the world's leading authority on waiting too long; don't
#
#
#         [Steve Rogers]
#         "Go ahead, Steve. No pressure."
#
#         Na podstawie:
#         Look, as maybe the world's leading authority on waiting too long; don't
#
#         Wcześniejsza opcja:
#         Oh, no
#
#
#         [Steve Rogers]
#         "Nothing."
#
#         Na podstawie:
#         Nobody's breaking any bylaws
#
#         Wcześniejsza opcja:
#         It's just, she's not the most
#
#
#         [Steve Rogers]
#         "And, Widow?"
#
#         Na podstawie:
#         You and Romanoff
#
#         Wcześniejsza opcja:
#         open person in the world
#
#
#         [Steve Rogers]
#         "You bet your ass."
#
#         Na podstawie:
#         I've seen her flirt, up close
#
#         Wcześniejsza opcja:
#         Clint, you've had a tough week, we won't hold it against you if you can't get it up
#
#
#         [Bruce Banner]
#         "The handle's imprinted, right?"
#
#         Na podstawie:
#         No, Natasha, she
#
#         Wcześniejsza opcja:
#         Smell the silent judgment
#
#
#         [Bruce Banner]
#         "Whosoever is carrying Thor's fingerprints"
#
#         Na podstawie:
#         Physics
#
#         Wcześniejsza opcja:
#         Oh this is gonna be beautiful
#
#
#         [Clint Barton]
#         "is, I think, the literal translation."
#
#         Na podstawie:
#         Uh, Whosoever be he worthy shall haveth the power
#
#         Wcześniejsza opcja:
#         I will be reinstituting Prima Nocta
#
#
#         [Tony Stark]
#         "Worthy."
#
#         Na podstawie:
#         I then rule Asgard
#
#         Wcześniejsza opcja:
#         Did you tell everyone about that
#
#
#         [Ultron]
#         "Or I was adream."
#
#         Na podstawie:
#         I'm sorry, I was asleep
#
#         Wcześniejsza opcja:
#         I will be reinstituting Prima Nocta
#
#
#         [Steve Rogers]
#         "Reboot Legionnaire OS."
#
#         Na podstawie:
#         Stark
#
#         Wcześniejsza opcja:
#         That's not a question I need answered
#
#
#         [Maria Hill]
#         "We got a buggy suit."
#
#         Na podstawie:
#         Steve, he said a bad language word
#
#         Wcześniejsza opcja:
#         I have a simpler one
#
#
#         [Tony Stark]
#         "There was this terrible noise."
#
#         Na podstawie:
#         Whosoever is carrying Thor's fingerprints is, I think, the literal translation
#
#         Wcześniejsza opcja:
#         Yes, well that's, uh, that's a very, very interesting theory
#
#
#         [Ultron]
#         "And I was tangled in..."
#
#         Na podstawie:
#         I'm sorry, I was asleep
#
#         Wcześniejsza opcja:
#         Whosoever is carrying Thor's fingerprints is, I think, the literal translation
#
#
#         [James Rhodes]
#         "In..."
#
#         Na podstawie:
#         Come on, Cap
#
#         Wcześniejsza opcja:
#         And
#
#
#         [Tony Stark]
#         "Strings."
#
#         Na podstawie:
#         JARVIS
#
#         Wcześniejsza opcja:
#         The handle's imprinted, right
#
#
#         [Tony Stark]
#         "Wouldn't have been my first call."
#
#         Na podstawie:
#         I will be reinstituting Prima Nocta
#
#         Wcześniejsza opcja:
#         Are you on my team
#
#
#         [Tony Stark]
#         "Who sent you?"
#
#         Na podstawie:
#         All deference to the man who wouldn't be king, but it's rigged
#
#         Wcześniejsza opcja:
#         Did you tell everyone about that
#
#
#         [Tony Stark]
#         "Ultron."
#
#         Na podstawie:
#         JARVIS
#
#         Wcześniejsza opcja:
#         He was a good guy
#
#
#         [Tony Stark]
#         "I'm on mission."
#
#         Na podstawie:
#         Are you on my team
#
#         Wcześniejsza opcja:
#         Come on, Cap
#
#
#         [Bruce Banner]
#         "What mission?"
#
#         Na podstawie:
#         Widow
#
#         Wcześniejsza opcja:
#         All deference to the man who wouldn't be king, but it's rigged
#
#
#         [Tony Stark]
#         "Rhodey!"
#
#         Na podstawie:
#         JARVIS
#
#         Wcześniejsza opcja:
#         Or, no, not yet
#
#
#         [Ultron]
#         "Sorry."
#
#         Na podstawie:
#         Worthy
#
#         Wcześniejsza opcja:
#         I'm sorry, I was asleep
#
#
#         [Tony Stark]
#         "Don't turn green."
#
#         Na podstawie:
#         Alright, let's go
#
#         Wcześniejsza opcja:
#         Did you tell everyone about that
#
#
#         [Tony Stark]
#         "I won't."
#
#         Na podstawie:
#         I will be reinstituting Prima Nocta
#
#         Wcześniejsza opcja:
#         I'm sorry, I was asleep
#
#
#         [James Rhodes]
#         "Come on!"
#
#         Na podstawie:
#         Come on, Cap
#
#         Wcześniejsza opcja:
#         I'm on a mission
#
#
#         [Bruce Banner]
#         "Please back away."
#
#         Na podstawie:
#         Sorry
#
#         Wcześniejsza opcja:
#         Did you tell everyone about that
#
#
#         [Bruce Banner]
#         "Thor!"
#
#         Na podstawie:
#         Ultron
#
#         Wcześniejsza opcja:
#         Whosoever is carrying Thor's fingerprints is, I think, the literal translation
#
#
#         [Tony Stark]
#         "Hey, Cap!"
#
#         Na podstawie:
#         Reboot, Legionnaire OS, we got a buggy suit
#
#         Wcześniejsza opcja:
#         Reboot, Legionnaire OS, we got a buggy suit
#
#
#         [Ultron]
#         "How is humanity saved"
#
#         Na podstawie:
#         and I was tangled in
#
#         Wcześniejsza opcja:
#         Is unsafe
#
#
#         [Ultron]
#         "With these? These puppets."
#
#         Na podstawie:
#         In the flesh
#
#         Wcześniejsza opcja:
#         But, down in the real world we're faced with ugly choices
#
#
#         [Ultron]
#         "The Avengers' extinction."
#
#         Na podstawie:
#         chrysalis
#
#         Wcześniejsza opcja:
#         In the flesh
#
#
#         [Ultron]
#         "There are no strings on me"
#
#         Na podstawie:
#         I'm on a mission
#
#         Wcześniejsza opcja:
#         Or, no, not yet
#
#
#         [Ultron]
#         "There are no strings on me"
#
#         Na podstawie:
#         I'm on a mission
#
#         Wcześniejsza opcja:
#         Or, no, not yet
#
#
#         [Ultron]
#         "But you can see There are no strings on me"
#
#         Na podstawie:
#         Wouldn't have been my first call
#
#         Wcześniejsza opcja:
#         We are here to help
#
#
#         [Ultron]
#         "All our work is gone."
#
#         Na podstawie:
#         There was a terrible noise
#
#         Wcześniejsza opcja:
#         We are here to help
#
#
#         [Ultron]
#         "Ultron cleared out. He used the Internet as an escape hatch."
#
#         Na podstawie:
#         I see a suit of armor around the world
#
#         Wcześniejsza opcja:
#         That's the one
#
#
#         [Natasha Romanoff]
#         "Nukes? He said he wanted us dead."
#
#         Na podstawie:
#         He said he wanted us dead
#
#         Wcześniejsza opcja:
#         You just didn't think it through
#
#
#         [Steve Rogers]
#         "He didn't say dead. He said extinct."
#
#         Na podstawie:
#         He didn't say dead
#
#         Wcześniejsza opcja:
#         You just didn't think it through
#
#
#         [Steve Rogers]
#         "Jarvis was the first line of defence."
#
#         Na podstawie:
#         JARVIS was the first line of defense
#
#         Wcześniejsza opcja:
#         That was dramatic
#
#
#         [Steve Rogers]
#         "He would have shut Ultron down."
#
#         Na podstawie:
#         He would've shut Ultron down, it makes sense
#
#         Wcześniejsza opcja:
#         He's been in everything
#
#
#         [Bruce Banner]
#         "No. Ultron could have assimilated Jarvis."
#
#         Na podstawie:
#         No, Ultron could've assimilated Jarvis
#
#         Wcześniejsza opcja:
#         There are no strings on me, no strings on me
#
#
#         [Thor]
#         "Trail went cold about 100 miles out, but it's headed north."
#
#         Na podstawie:
#         Trail went cold about a hundred miles out but it's headed north, and it has the scepter
#
#         Wcześniejsza opcja:
#         You just didn't think it through
#
#
#         [Natasha Romanoff]
#         "Genie's out of that bottle."
#
#         Na podstawie:
#         The genie's out of that bottle
#
#         Wcześniejsza opcja:
#         That's the one
#
#
#         [Clint Barton]
#         "Saved New York?"
#
#         Na podstawie:
#         Woah, woah, woah
#
#         Wcześniejsza opcja:
#         You built this program
#
#
#         [Iron Legion]
#         "Together."
#
#         Na podstawie:
#         Please back away
#
#         Wcześniejsza opcja:
#         You just roll over, show your belly, every time somebody snarls
#
#
#         [Bruce Banner]
#         "Thor's right. Ultron's calling us out."
#
#         Na podstawie:
#         Ultron cleared out, used the internet as an escape hatch
#
#         Wcześniejsza opcja:
#         Why is it trying to kill us
#
#
#         [Thor]
#         "But sooner or later, every man shows himself."
#
#         Na podstawie:
#         Trail went cold about a hundred miles out but it's headed north, and it has the scepter
#
#         Wcześniejsza opcja:
#         This could've been avoided if you hadn't played with something you don't understand
#
#
#         [Steve Rogers]
#         "Make him selfdestruct."
#
#         Na podstawie:
#         Let's start making it smaller
#
#         Wcześniejsza opcja:
#         Why is it trying to kill us
#
#
#         [Ultron]
#         "Men of peace create engines of war."
#
#         Na podstawie:
#         Men of peace create engines of war, invaders create avengers, people create
#
#         Wcześniejsza opcja:
#         A hostile alien army came charging through a hole in space
#
#
#         [Ultron]
#         "Invaders create Avengers."
#
#         Na podstawie:
#         Men of peace create engines of war, invaders create avengers, people create
#
#         Wcześniejsza opcja:
#         The Avengers were supposed to be different than SHIELD
#
#
#         [Ultron]
#         "People create"
#
#         Na podstawie:
#         Men of peace create engines of war, invaders create avengers, people create
#
#         Wcześniejsza opcja:
#         The Avengers were supposed to be different than SHIELD
#
#
#         [Pietro Maximoff]
#         "We were 10 years old."
#
#         Na podstawie:
#         We were ten years old, having dinner, the four of us
#
#         Wcześniejsza opcja:
#         We weren't even close
#
#
#         [Pietro Maximoff]
#         "Our parents go in"
#
#         Na podstawie:
#         Our parents go in, and the whole building starts coming apart
#
#         Wcześniejsza opcja:
#         And when you get inside the rest of their heads
#
#
#         [Pietro Maximoff]
#         "Three feet from our faces."
#
#         Na podstawie:
#         sits there in the rubble, three feet from our faces
#
#         Wcześniejsza opcja:
#         And when you get inside the rest of their heads
#
#
#         [Maria Hill]
#         "Robotics labs, weapons facilities, jet propulsion labs."
#
#         Na podstawie:
#         Robotics labs, weapons facilities, jet propulsion labs, reports of a metal man, or men, coming in and emptying the place
#
#         Wcześniejsza opcja:
#         This is a start, but there's something we need to begin the real work
#
#
#         [Maria Hill]
#         "Not any more."
#
#         Na podstawie:
#         Not anymore
#
#         Wcześniejsza opcja:
#         But you needed something more than a man
#
#
#         [Ultron]
#         "Yes, ma'am."
#
#         Na podstawie:
#         No, please
#
#         Wcześniejsza opcja:
#         But alsoâ€¦ yeah
#
#
#         [Ultron]
#         "I gotta go."
#
#         Na podstawie:
#         I've come to save the world
#
#         Wcześniejsza opcja:
#         Now I don't
#
#
#         [Tony Stark]
#         "Who was that?"
#
#         Na podstawie:
#         That's
#
#         Wcześniejsza opcja:
#         Only when engaged
#
#
#         [Ultron]
#         "Girlfriend."
#
#         Na podstawie:
#         end
#
#         Wcześniejsza opcja:
#         Me
#
#
#         [Ultron]
#         "Yeah, I bet he... Yeah."
#
#         Na podstawie:
#         Oh, I'm sure they do
#
#         Wcześniejsza opcja:
#         Now I don't
#
#
#         [Ultron]
#         "Known associates."
#
#         Na podstawie:
#         smaller people
#
#         Wcześniejsza opcja:
#         And on the side of the shell is painted one word
#
#
#         [Tony Stark]
#         "Baron Strucker had a lot of friends."
#
#         Na podstawie:
#         A hostile alien army came charging through a hole in space
#
#         Wcześniejsza opcja:
#         That's a negative
#
#
#         [Maria Hill]
#         "Black market arms."
#
#         Na podstawie:
#         Robotics labs, weapons facilities, jet propulsion labs, reports of a metal man, or men, coming in and emptying the place
#
#         Wcześniejsza opcja:
#         Robotics labs, weapons facilities, jet propulsion labs, reports of a metal man, or men, coming in and emptying the place
#
#
#         [Ultron]
#         "Wakanada."
#
#         Na podstawie:
#         Harmony
#
#         Wcześniejsza opcja:
#         What's this
#
#
#         [Ultron]
#         "Wakanda."
#
#         Na podstawie:
#         Harmony
#
#         Wcześniejsza opcja:
#         Uh, it's a tattoo
#
#
#         [Bruce Banner]
#         "Strucker's prize pupils."
#
#         Na podstawie:
#         Wakanda
#
#         Wcześniejsza opcja:
#         We wait for two days for Tony Stark to kill us
#
#
#         [Bruce Banner]
#         "Cuttlefish."
#
#         Na podstawie:
#         Wakanda
#
#         Wcześniejsza opcja:
#         I sent you six short range heat seekers and got a boat full of rusted parts
#
#
#         [Tony Stark]
#         "Deep sea fish."
#
#         Na podstawie:
#         He operates off the African coast, black market arms
#
#         Wcześniejsza opcja:
#         He operates off the African coast, black market arms
#
#
#         [Steve Rogers]
#         "They make lights, disco lights..."
#
#         Na podstawie:
#         Strucker knew something that Ultron wanted us to miss
#
#         Wcześniejsza opcja:
#         Now, you will make it right, or the next missile I send you will come very much faster
#
#
#         [Clint Barton]
#         "Let's talk business."
#
#         Na podstawie:
#         Gotta go
#
#         Wcześniejsza opcja:
#         you didn't know
#
#
#         [Clint Barton]
#         "Vibranium."
#
#         Na podstawie:
#         Girlfriend
#
#         Wcześniejsza opcja:
#         I sent you six short range heat seekers and got a boat full of rusted parts
#
#
#         [Tony Stark]
#         "It's worth billions."
#
#         Na podstawie:
#         You meet people, I didn't sell him anything
#
#         Wcześniejsza opcja:
#         Now, you will make it right, or the next missile I send you will come very much faster
#
#
#         [Bruce Banner]
#         "Stark."
#
#         Na podstawie:
#         Wa
#
#         Wcześniejsza opcja:
#         What's this
#
#
#         [Ultron]
#         "His hollow men?"
#
#         Na podstawie:
#         You think I'm one of Stark's puppets, his hollow men
#
#         Wcześniejsza opcja:
#         But then, he knew what kind of world he was helping create
#
#
#         [Ulysses Klaue]
#         "Junior."
#
#         Na podstawie:
#         Cuttlefish
#
#         Wcześniejsza opcja:
#         Strucker's prize pupils
#
#
#         [Ultron]
#         "Clearly you've never made an omelette."
#
#         Na podstawie:
#         Clearly you've never made an omelet
#
#         Wcześniejsza opcja:
#         It's a word in an African dialect meaning thief, in a much less friendly way
#
#
#         [Wanda Maximoff]
#         "Yes. He's funny."
#
#         Na podstawie:
#         Oh, we will
#
#         Wcześniejsza opcja:
#         But then, he knew what kind of world he was helping create
#
#
#         [Tony Stark]
#         "Mr Stark."
#
#         Na podstawie:
#         Ahh, Junior
#
#         Wcześniejsza opcja:
#         Stark
#
#
#         [Tony Stark]
#         "God's righteous man."
#
#         Na podstawie:
#         Ahh, Junior
#
#         Wcześniejsza opcja:
#         You think I'm one of Stark's puppets, his hollow men
#
#
#         [Steve Rogers]
#         "Thor, status."
#
#         Na podstawie:
#         Status
#
#         Wcześniejsza opcja:
#         Captain America
#
#
#         [Thor]
#         "Take special care."
#
#         Na podstawie:
#         Take special care, I doubt a human could keep her at bay
#
#         Wcześniejsza opcja:
#         But I always say, Keep your friends rich and your enemies rich, and wait to find out which is which
#
#
#         [Peggy Carter]
#         "The war is over, Steve."
#
#         Na podstawie:
#         The war's over, Steve
#
#         Wcześniejsza opcja:
#         This is going very well
#
#
#         [Ultron]
#         "News or footage. Keyword, Hulk."
#
#         Na podstawie:
#         Captain America
#
#         Wcześniejsza opcja:
#         Can you not see
#
#
#         [Pietro Maximoff]
#         "You got no backup here."
#
#         Na podstawie:
#         I'll be right back
#
#         Wcześniejsza opcja:
#         Yeah, you better run
#
#
#         [Heimdall]
#         "I'm calling in Veronica."
#
#         Na podstawie:
#         They see you leading us to Hel
#
#         Wcześniejsza opcja:
#         I have no place in the world
#
#
#         [Ultron]
#         "Go! Keep moving!"
#
#         Na podstawie:
#         Let's talk business
#
#         Wcześniejsza opcja:
#         Move, move, move
#
#
#         [Pietro Maximoff]
#         "All right, everybody, stand down!"
#
#         Na podstawie:
#         I'll be right back
#
#         Wcześniejsza opcja:
#         And you're not going anywhere
#
#
#         [Ulysses Klaue]
#         "You're stronger than her."
#
#         Na podstawie:
#         You're one of his
#
#         Wcześniejsza opcja:
#         You'll break them
#
#
#         [Ulysses Klaue]
#         "You're smarter than her."
#
#         Na podstawie:
#         You're one of his
#
#         Wcześniejsza opcja:
#         You'll break them
#
#
#         [Heimdall]
#         "You're Bruce Banner."
#
#         Na podstawie:
#         They see you leading us to Hel
#
#         Wcześniejsza opcja:
#         You'll break them
#
#
#         [Ulysses Klaue]
#         "Okay!"
#
#         Na podstawie:
#         Yeah
#
#         Wcześniejsza opcja:
#         I'm gonna kill him
#
#
#         [Heimdall]
#         "In the back?"
#
#         Na podstawie:
#         Is that the first son of Odin
#
#         Wcześniejsza opcja:
#         The ceremony is necessary for you to take your place in the world
#
#
#         [Ultron]
#         "Dick move, Banner."
#
#         Na podstawie:
#         Captain America
#
#         Wcześniejsza opcja:
#         Alright everybody, stand down
#
#
#         [Pietro Maximoff]
#         "Everybody, out!"
#
#         Na podstawie:
#         I'll be right back
#
#         Wcześniejsza opcja:
#         Alright everybody, stand down
#
#
#         [Ultron]
#         "Damage report?"
#
#         Na podstawie:
#         Captain America
#
#         Wcześniejsza opcja:
#         Only the breakable ones
#
#
#         [Ulysses Klaue]
#         "That's comprehensive."
#
#         Na podstawie:
#         I'm afraid that I'm not that afraid
#
#         Wcześniejsza opcja:
#         The ceremony is necessary for you to take your place in the world
#
#
#         [Ulysses Klaue]
#         "Show me something."
#
#         Na podstawie:
#         Shoot them
#
#         Wcześniejsza opcja:
#         You gotta work with me
#
#
#         [Ultron]
#         "Go, go, go!"
#
#         Na podstawie:
#         Let's talk business
#
#         Wcześniejsza opcja:
#         Go to sleep, go to sleep, go to sleep
#
#
#         [Ulysses Klaue]
#         "Flank him, flank him!"
#
#         Na podstawie:
#         Shoot them
#
#         Wcześniejsza opcja:
#         Show me something
#
#
#         [Ultron]
#         "There's been no official call for Banner's arrest"
#
#         Na podstawie:
#         There is no man in charge
#
#         Wcześniejsza opcja:
#         No, not that way, not that way
#
#
#         [Tony Stark]
#         "So, run and hide?"
#
#         Na podstawie:
#         Alright everybody, stand down
#
#         Wcześniejsza opcja:
#         And you're not going anywhere
#
#
#         [Tony Stark]
#         "Safe house."
#
#         Na podstawie:
#         Okay, pal, we're gonna get you out of town
#
#         Wcześniejsza opcja:
#         A safe house
#
#
#         [Tony Stark]
#         "Honey?"
#
#         Na podstawie:
#         Come on, Bruce
#
#         Wcześniejsza opcja:
#         Honey, I'm home
#
#
#         [Tony Stark]
#         "These are smaller agents."
#
#         Na podstawie:
#         smaller agents
#
#         Wcześniejsza opcja:
#         That's comprehensive
#
#
#         [Clint Barton]
#         "Honey."
#
#         Na podstawie:
#         Company
#
#         Wcześniejsza opcja:
#         Honey, I'm home
#
#
#         [Tony Stark]
#         "She's..."
#
#         Na podstawie:
#         We'll shake it off
#
#         Wcześniejsza opcja:
#         He kept it off SHIELD's files, I'd like to keep it that way
#
#
#         [Clint Barton]
#         "Nathaniel."
#
#         Na podstawie:
#         Company
#
#         Wcześniejsza opcja:
#         Dad
#
#
#         [Clint Barton]
#         "Traitor."
#
#         Na podstawie:
#         Company
#
#         Wcześniejsza opcja:
#         There's been no official call for Banner's arrest, but it's in the air
#
#
#         [Clint Barton]
#         "Thor?"
#
#         Na podstawie:
#         Company
#
#         Wcześniejsza opcja:
#         She'sâ€¦Nathaniel
#
#
#         [Maria Hill]
#         "I saw something in that dream."
#
#         Na podstawie:
#         There's been no official call for Banner's arrest, but it's in the air
#
#         Wcześniejsza opcja:
#         Well for now I'd stay in stealth mode, and stay away from here
#
#
#         [Clint Barton]
#         "Yeah, that's not gonna sell."
#
#         Na podstawie:
#         Oh, my goodness
#
#         Wcześniejsza opcja:
#         If they're sleeping here, some of them are gonna have to double up
#
#
#         [Clint Barton]
#         "What about Nat and Dr Banner?"
#
#         Na podstawie:
#         Honey, I'm home
#
#         Wcześniejsza opcja:
#         I know all your names
#
#
#         [Clint Barton]
#         "How long has that been going on?"
#
#         Na podstawie:
#         How you guys doing
#
#         Wcześniejsza opcja:
#         Already on the scene
#
#
#         [Clint Barton]
#         "Well, okay."
#
#         Na podstawie:
#         No, I'm good
#
#         Wcześniejsza opcja:
#         See, you worried for nothing
#
#
#         [Clint Barton]
#         "Nat seems really shaken."
#
#         Na podstawie:
#         Gentleman, this is Laura
#
#         Wcześniejsza opcja:
#         Did you bring Auntie Nat
#
#
#         [Laura Barton]
#         "Those gods..."
#
#         Na podstawie:
#         Honey
#
#         Wcześniejsza opcja:
#         But I see those guys, those Gods
#
#
#         [Bruce Banner]
#         "Kids."
#
#         Na podstawie:
#         They used up all the hot water
#
#         Wcześniejsza opcja:
#         I can't have this, kids
#
#
#         [Tony Stark]
#         "Why, Ms Barton, you little minx."
#
#         Na podstawie:
#         I don't trust a guy without a dark side
#
#         Wcześniejsza opcja:
#         Barton, you little minx
#
#
#         [Nick Fury]
#         "Find our unknown."
#
#         Na podstawie:
#         My contacts all say he's building something
#
#         Wcześniejsza opcja:
#         Here we all are, back on earth, with nothing but our wit, and our will to save the world
#
#
#         [Nick Fury]
#         "Ears, everywhere else."
#
#         Na podstawie:
#         Guy's multiplying faster than a Catholic rabbit
#
#         Wcześniejsza opcja:
#         Back in the day, I had eyes everywhere, ears everywhere else
#
#
#         [Nick Fury]
#         "between him and his mission."
#
#         Na podstawie:
#         Yeah, well, I contacted our friends at the NEXUS about that
#
#         Wcześniejsza opcja:
#         When you two programmed him to protect the human race, you amazingly failed
#
#
#         [Bruce Banner]
#         "Oldschool spy stuff?"
#
#         Na podstawie:
#         Anything on Nat
#
#         Wcześniejsza opcja:
#         Any chance Natasha might leave you a message, outside the internet, old school spy stuff
#
#
#         [Bruce Banner]
#         "Kind of don't."
#
#         Na podstawie:
#         I can work on tissue degeneration, if you can fry whatever operational system Cho implanted
#
#         Wcześniejsza opcja:
#         Stark will take care of it
#
#
#         [Tony Stark]
#         "can beat Ultron's?"
#
#         Na podstawie:
#         Scattered, dumped his memory
#
#         Wcześniejsza opcja:
#         And you just assume that JARVIS' operational matrix can beat Ultron's
#
#
#         [Bruce Banner]
#         "Thor."
#
#         Na podstawie:
#         What, the gem
#
#         Wcześniejsza opcja:
#         Thor, you helped create this
#
#
#         [Thor]
#         "and saw annihilation."
#
#         Na podstawie:
#         But with it on our side
#
#         Wcześniejsza opcja:
#         I looked in your head and saw annihilation
#
#
#         [Ultron]
#         "Come on."
#
#         Na podstawie:
#         I've moved beyond your mission
#
#         Wcześniejsza opcja:
#         Get off the bridge
#
#
#         [Ultron]
#         "What?"
#
#         Na podstawie:
#         Alright
#
#         Wcześniejsza opcja:
#         What, you think you're the only one stalling
#
#
#         [FRIDAY]
#         "Function, still unclear."
#
#         Na podstawie:
#         Boss, it's working
#
#         Wcześniejsza opcja:
#         Well, that is the mission
#
#
#         [Clint Barton]
#         "will be metal."
#
#         Na podstawie:
#         Go, go, move
#
#         Wcześniejsza opcja:
#         When the dust settles, the only thing living in this world will be metal
#
#
#         [Clint Barton]
#         "Global extinction."
#
#         Na podstawie:
#         And I can't do my job and babysit
#
#         Wcześniejsza opcja:
#         Right now the impact would kill thousands
#
#
#         [Tony Stark]
#         "I got about 50 to 100 more coming in after this group."
#
#         Na podstawie:
#         Rhodey, get the rest of the people on board that carrier
#
#         Wcześniejsza opcja:
#         I turn that key and drop this rock a little early and it's still billions dead
#
#
#         [Ultron]
#         "Nat."
#
#         Na podstawie:
#         I got no strings, so I have fun
#
#         Wcześniejsza opcja:
#         Say hi to Auntie Nat
#
#
#         [Natasha Romanoff]
#         "Zrinka!"
#
#         Na podstawie:
#         Right
#
#         Wcześniejsza opcja:
#         They're good
#
#
#         [Nick Fury]
#         "Costel! Baby!"
#
#         Na podstawie:
#         But with Stark's stealth tech, we still can't track the damn thing
#
#         Wcześniejsza opcja:
#         And you're gonna miss me
#
#
#         [Natasha Romanoff]
#         "Fine."
#
#         Na podstawie:
#         Right
#
#         Wcześniejsza opcja:
#         I'm fine
#
#
#         [Tony Stark]
#         "Well..."
#
#         Na podstawie:
#         Triple Yahtzee
#
#         Wcześniejsza opcja:
#         Well, the Vision's artificial intelligence
#
#
#         [Steve Rogers]
#         "Trouble, Ms Romanoff."
#
#         Na podstawie:
#         I'm home
#
#         Wcześniejsza opcja:
#         Nothing lasts forever
